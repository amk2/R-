# %%
# https://www.tutorialspoint.com/r/r_json_files.htm
# Load the package required to read JSON files.
library("rjson")

# %%
# Give the input file name to the function.
result <- fromJSON(file = "browse.json")

# %%
# Convert JSON file to a data frame.
json_data_frame <- as.data.frame(result, row.names = NULL, check.rows = TRUE, check.names = TRUE)
# Out:
# Error in (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE, : arguments imply differing number of rows: 0, 1
# Traceback:
#
# 1. as.data.frame(result, row.names = NULL, check.rows = TRUE, check.names = TRUE)
# 2. as.data.frame.list(result, row.names = NULL, check.rows = TRUE,
#  .     check.names = TRUE)
# 3. do.call(data.frame, c(x, alis))
# 4. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#  .     fix.empty.names = TRUE, stringsAsFactors = default.stringsAsFactors())
#  . {
#  .     data.row.names <- if (check.rows && is.null(row.names))
#  .         function(current, new, i) {
#  .             if (is.character(current))
#  .                 new <- as.character(new)
#  .             if (is.character(new))
#  .                 current <- as.character(current)
#  .             if (anyDuplicated(new))
#  .                 return(current)
#  .             if (is.null(current))
#  .                 return(new)
# ...

# %%
print(json_data_frame)
